# %%
print("heelo")
# Out:
# heelo

# %% [markdown]
# ## Next Code

# %%
a=10
print(a)
# Out:
# 10

# %%
for i in range(0,10,2):
    print(str(i + 1)+"Pakistan")
# Out:
# 1Pakistan
# 3Pakistan
# 5Pakistan
# 7Pakistan
# 9Pakistan

# %%
i=1
while i <= 10:
    print(i ,"Ali")
    i= i+1
# Out:
# 1 Ali
# 2 Ali
# 3 Ali
# 4 Ali
# 5 Ali
# 6 Ali
# 7 Ali
# 8 Ali
# 9 Ali
# 10 Ali

# %% [markdown]
# ## List

# %%
cities=["Lahore", "Karachi","Islamabad"]
# city=cities[1]
# print(city, cities)
cities.append("Multan")
cities.append("Ali")
cities[3]="singapura"
cities.insert(3,"Bahwalpur")
del cities[2]
cities
# Out:
# ['Lahore', 'Karachi', 'Bahwalpur', 'singapura', 'Ali']

# %%
names=["Ali", "Usman", "Ahmad","usama"]
# for i,j in enumerate(names, start=1):
#     print(i, j)

for i in names:
    if "Ali1" in i:
        print(i +" is found" )
        break
    else:
        print("Not Found")
        break
# Out:
# Not Found

# %%
cities = ["Lahore", "Karachi", "Islamabad"]

city = "Karachi1"

if city in cities:
    if "Lahore" in city:
        print(city + " is Clean City")
    else:
        print(city + " is not clean city")
else:
    print("City not in list")
# Out:
# City not in list

# %%
a=["a", "b"]
b=["c","d"]
a.extend(b)
print(a)
# Out:
# ['a', 'b', 'c', 'd']

# %% [markdown]
# ## List Comprehension

# %%
lista=["Adil", "Ali", "Usman"]
# listb=[i for i in lista]
# print(listb)

# for i in lista:
# if "Adil" in lista:
#     print("Adil is here")
#         # break
# else:
#     print(" Not Here")
#         # break
result=["yes" for i in lista if "Adil" in i]
print(result[0])
# Out:
# yes

# %% [markdown]
# ## Tuple

# %%
tup=("omer",)
y= list(tup)
y.append("usman")
y.insert(0,"Ali")
y.insert(0,0)
tup =tuple(y)
print(tup,type(tup))
# Out:
# (0, 'Ali', 'omer', 'usman') <class 'tuple'>

# %%
tup1=("Ali",)
tup2=("Salman",)
tup1 +=tup2
print(tup1)
# Out:
# ('Ali', 'Salman')

# %%
tup1 = ("Ali", "usman")
tup2 = ("Salman", "khalid")

result = [tup1, tup2]
print(result)
# Out:
# [('Ali', 'usman'), ('Salman', 'khalid')]

# %%
cities = ["Lahore", "Karachi", "Islamabad"]
names = ["Ali", "Usman", "Ahmad", "Usama"]

for index, (name, city) in enumerate(zip(names, cities), start=1):
    print(index, name, city)
# Out:
# 1 Ali Lahore
# 2 Usman Karachi
# 3 Ahmad Islamabad
